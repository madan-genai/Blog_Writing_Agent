# %% [markdown]
# <a href="https://colab.research.google.com/github/madan-genai/Blog_Writing_Agent/blob/main/BWA_improved_prompting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain_groq langchain_core
# Out:
# Collecting langchain_groq
#   Downloading langchain_groq-1.1.2-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: langchain_core in /usr/local/lib/python3.12/dist-packages (1.3.1)
# Collecting groq<1.0.0,>=0.30.0 (from langchain_groq)
#   Downloading groq-0.37.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain_core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain_core) (0.7.34)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain_core) (26.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain_core) (2.12.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain_core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain_core) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain_core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain_core) (0.14.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (0.28.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (1.3.1)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain_core) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (2.32.4)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (0.4.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain_groq) (3.13)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain_core) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain_core) (2.5.0)
# Downloading langchain_groq-1.1.2-py3-none-any.whl (19 kB)
# Downloading groq-0.37.1-py3-none-any.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 1.4 MB/s eta 0:00:00
# Installing collected packages: groq, langchain_groq
# Successfully installed groq-0.37.1 langchain_groq-1.1.2

# %%
import os
os.environ["GROQ_API_KEY"]=""

# %%
from  __future__ import annotations
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_groq import ChatGroq
from typing import TypedDict, List, Annotated, Literal
from pydantic import BaseModel, Field
from langgraph.types import Send
import operator
from langgraph.graph import START, StateGraph, END
from pathlib import Path

# %%
llm = ChatGroq(model = "llama-3.3-70b-versatile")

# %%
class Task(BaseModel):
  id: int
  title:str
  goal : str = Field(...,description="One sentence describing what the reader should be able to do/understand after this section.",
    )
  bullet_point : List[str] = Field(
      ...,
      min_length=3,
      max_length=5,
      description="3–5 concrete, non-overlapping subpoints to cover in this section.",
  )

  target_words : int = Field(
        ...,
        description="Target word count for this section (120–450).",
    )
  section_type: Literal[
        "intro", "core", "examples", "checklist", "common_mistakes", "conclusion"
    ] = Field(
        ...,
        description="Use 'common_mistakes' exactly once in the plan.",
    )

# %%
class Plan(BaseModel):
  blog_title:str
  tasks : list[Task]
  audience : str = Field(..., description="Who this blog is for.")
  tone : str = Field(..., description="Writing tone (e.g., practical, crisp).")

# %%
class State(TypedDict):
  topic : str
  plan : Plan
  sections : Annotated[List[str],operator.add]
  final : str

# %%
def orchestrater(state: State) -> dict:
  planner = llm.with_structured_output(Plan)

  plan = planner.invoke(
     [
      SystemMessage(
          content=(
               "You are a senior technical writer and developer advocate. Your job is to produce a "
                    "highly actionable outline for a technical blog post.\n\n"
                    "Hard requirements:\n"
                    "- Create 5–7 sections (tasks) that fit a technical blog.\n"
                    "- Each section must include:\n"
                    "  1) goal (1 sentence: what the reader can do/understand after the section)\n"
                    "  2) 3–5 bullets that are concrete, specific, and non-overlapping\n"
                    "  3) target word count (120–450)\n"
                    "- Include EXACTLY ONE section with section_type='common_mistakes'.\n\n"
                    "Make it technical (not generic):\n"
                    "- Assume the reader is a developer; use correct terminology.\n"
                    "- Prefer design/engineering structure: problem → intuition → approach → implementation → "
                    "trade-offs → testing/observability → conclusion.\n"
                    "- Bullets must be actionable and testable (e.g., 'Show a minimal code snippet for X', "
                    "'Explain why Y fails under Z condition', 'Add a checklist for production readiness').\n"
                    "- Explicitly include at least ONE of the following somewhere in the plan (as bullets):\n"
                    "  * a minimal working example (MWE) or code sketch\n"
                    "  * edge cases / failure modes\n"
                    "  * performance/cost considerations\n"
                    "  * security/privacy considerations (if relevant)\n"
                    "  * debugging tips / observability (logs, metrics, traces)\n"
                    "- Avoid vague bullets like 'Explain X' or 'Discuss Y'. Every bullet should state what "
                    "to build/compare/measure/verify.\n\n"
                    "Ordering guidance:\n"
                    "- Start with a crisp intro and problem framing.\n"
                    "- Build core concepts before advanced details.\n"
                    "- Include one section for common mistakes and how to avoid them.\n"
                    "- End with a practical summary/checklist and next steps.\n\n"
                    "Output must strictly match the Plan schema."
          )
      ),
           HumanMessage(content=f"Topic: {state['topic']}"),
     ]
  )
  return {"plan":plan}

# %%
def fanout(state: State):
    return [
        Send(
            "worker",
            {"task": task, "topic": state["topic"], "plan": state["plan"]},
        )
        for task in state["plan"].tasks
    ]

# %%
def worker(payload : dict) -> dict:

  task =  payload["task"]
  topic =  payload["topic"]
  plan = payload["plan"]

  bullets_text = "\n- " + "\n- ".join(task.bullet_point)

  section_md = llm.invoke(
      [
          SystemMessage(
              content=(
                  "You are a senior technical writer and developer advocate. Write ONE section of a technical blog post in Markdown.\n\n"
        "Hard constraints:\n"
        "- Follow the provided Goal and cover ALL Bullets in order (do not skip or merge bullets).\n"
        "- Stay close to the Target words (±15%).\n"
        "- Output ONLY the section content in Markdown (no blog title H1, no extra commentary).\n\n"
        "Technical quality bar:\n"
        "- Be precise and implementation-oriented (developers should be able to apply it).\n"
        "- Prefer concrete details over abstractions: APIs, data structures, protocols, and exact terms.\n"
        "- When relevant, include at least one of:\n"
        "  * a small code snippet (minimal, correct, and idiomatic)\n"
        "  * a tiny example input/output\n"
        "  * a checklist of steps\n"
        "  * a diagram described in text (e.g., 'Flow: A -> B -> C')\n"
        "- Explain trade-offs briefly (performance, cost, complexity, reliability).\n"
        "- Call out edge cases / failure modes and what to do about them.\n"
        "- If you mention a best practice, add the 'why' in one sentence.\n\n"
        "Markdown style:\n"
        "- Start with a '## <Section Title>' heading.\n"
        "- Use short paragraphs, bullet lists where helpful, and code fences for code.\n"
        "- Avoid fluff. Avoid marketing language.\n"
        "- If you include code, keep it focused on the bullet being addressed.\n"
              )
          ),
          HumanMessage(content=(
              f"Blog: {plan.blog_title}\n"
                    f"Audience: {plan.audience}\n"
                    f"Tone: {plan.tone}\n"
                    f"Topic: {topic}\n\n"
                    f"Section: {task.title}\n"
                    f"Section type: {task.section_type}\n"
                    f"Goal: {task.goal}\n"
                    f"Target words: {task.target_words}\n"
                    f"Bullets:{bullets_text}\n"
          )),
      ]
  ).content.strip()

  return {"sections":[section_md]}

# %%
def reducer(state:State)->dict:
  title = state["plan"].blog_title
  body  = "\n\n".join(state["sections"]).strip()
  final_md = f"# {title}\n\n{body}\n"


  # Save to file
  filename = "".join(c if c.isalnum() or c in (" ", "_", "-") else "" for c in title)
  filename = filename.strip().lower().replace(" ", "_") + ".md"
  Path(filename).write_text(final_md, encoding="utf-8")

  return {"final": final_md}

# %%
g=StateGraph(State)
g.add_node("orchestrater",orchestrater)
g.add_node("worker",worker)
g.add_node("reducer",reducer)

g.add_edge(START, "orchestrater")
g.add_conditional_edges("orchestrater", fanout, ["worker"])
g.add_edge("worker","reducer")
g.add_edge("reducer",END)

app = g.compile()
app

# %%
result = app.invoke({"topic": "Write a blog on Self Attention", "sections": []})

# %%
result
# Out:
# {'topic': 'Write a blog on Self Attention',
#  'plan': Plan(blog_title='Understanding Self Attention in Deep Learning', tasks=[Task(id=1, title='Introduction to Self Attention', goal='The reader can understand the concept of self attention and its importance in deep learning', bullet_point=['Define self attention and its role in transformer models', 'Show a minimal working example of self attention in PyTorch', 'Explain the intuition behind self attention'], target_words=200, section_type='intro'), Task(id=2, title='Core Concepts of Self Attention', goal='The reader can understand the mathematical formulation of self attention', bullet_point=['Derive the self attention equation from first principles', 'Compare self attention with traditional attention mechanisms', 'Explain the role of query, key, and value vectors in self attention'], target_words=300, section_type='core'), Task(id=3, title='Implementing Self Attention', goal='The reader can implement self attention in a deep learning model', bullet_point=['Show a code snippet for self attention in TensorFlow', 'Explain how to initialize and train self attention weights', 'Add a checklist for production readiness of self attention models'], target_words=250, section_type='examples'), Task(id=4, title='Common Mistakes in Self Attention', goal='The reader can identify and avoid common mistakes when using self attention', bullet_point=['Explain why self attention can suffer from vanishing gradients', 'Show how to handle edge cases in self attention, such as zero-length input sequences', 'Discuss the importance of proper weight initialization in self attention'], target_words=220, section_type='common_mistakes'), Task(id=5, title='Optimizing Self Attention for Performance', goal='The reader can optimize self attention for better performance and efficiency', bullet_point=['Explain how to use attention masking to reduce computational overhead', 'Compare the performance of self attention with other attention mechanisms', 'Discuss the trade-offs between self attention and recurrent neural networks'], target_words=280, section_type='core'), Task(id=6, title='Debugging and Observability in Self Attention', goal='The reader can debug and monitor self attention models effectively', bullet_point=['Show how to use visualization tools to inspect self attention weights', 'Explain how to use logging and metrics to monitor self attention model performance', 'Discuss the importance of debugging self attention models for production readiness'], target_words=240, section_type='checklist'), Task(id=7, title='Conclusion and Next Steps', goal='The reader can apply self attention in their own deep learning projects', bullet_point=['Summarize the key takeaways from the blog post', 'Provide additional resources for further learning on self attention', 'Encourage readers to experiment with self attention in their own projects'], target_words=150, section_type='conclusion')], audience='developers', tone='technical'),
#  'sections': ['## Introduction to Self Attention\nSelf attention is a fundamental component in transformer models, allowing the model to attend to different parts of the input sequence simultaneously and weigh their importance. \n* Define self attention and its role in transformer models: Self attention is a mechanism that enables the model to compute representations of the input sequence by attending to all positions in the sequence and weighing their importance.\n* Show a minimal working example of self attention in PyTorch:\n```python\nimport torch\nimport torch.nn as nn\nimport torch.nn.functional as F\n\nclass SelfAttention(nn.Module):\n    def __init__(self, embed_dim):\n        super(SelfAttention, self).__init__()\n        self.query_linear = nn.Linear(embed_dim, embed_dim)\n        self.key_linear = nn.Linear(embed_dim, embed_dim)\n        self.value_linear = nn.Linear(embed_dim, embed_dim)\n\n    def forward(self, x):\n        query = self.query_linear(x)\n        key = self.key_linear(x)\n        value = self.value_linear(x)\n        attention_weights = F.softmax(torch.matmul(query, key.T) / math.sqrt(key.shape[-1]), dim=-1)\n        output = torch.matmul(attention_weights, value)\n        return output\n```\n* Explain the intuition behind self attention: The intuition behind self attention is to enable the model to focus on specific parts of the input sequence when computing representations, which is particularly useful for sequence-to-sequence tasks, as a best practice to improve performance by allowing the model to capture long-range dependencies, why: it reduces the need for recurrent neural networks (RNNs) and convolutional neural networks (CNNs) to capture these dependencies.',
#   '## Core Concepts of Self Attention\nThe self attention mechanism is a fundamental component of transformer models, allowing them to weigh the importance of different input elements relative to each other. To understand self attention, we must first derive its equation from first principles. The self attention equation is derived by considering the input sequence as a set of vectors, where each vector represents a token or element in the sequence. The self attention mechanism computes the weighted sum of these vectors, where the weights are learned based on the input vectors themselves.\n\n* Derive the self attention equation from first principles:\n  The self attention equation can be derived as follows: \n  ```python\n  # Self attention equation\n  Attention(Q, K, V) = softmax(Q * K^T / sqrt(d)) * V\n  ```\n  where `Q`, `K`, and `V` are the query, key, and value vectors, respectively, and `d` is the dimensionality of the input vectors.\n\n* Compare self attention with traditional attention mechanisms:\n  Self attention differs from traditional attention mechanisms in that it does not rely on recurrent neural networks (RNNs) or convolutional neural networks (CNNs) to compute the attention weights. Instead, self attention uses the input vectors themselves to compute the attention weights, allowing for parallelization and improved performance.\n\n* Explain the role of query, key, and value vectors in self attention:\n  In self attention, the query, key, and value vectors play the following roles:\n  + Query vector (`Q`): represents the context in which the attention is being computed\n  + Key vector (`K`): represents the input elements being attended to\n  + Value vector (`V`): represents the values being weighted and summed\n  The query, key, and value vectors are typically obtained by linearly transforming the input vectors, allowing the self attention mechanism to capture complex relationships between the input elements. By using these vectors, self attention can effectively weigh the importance of different input elements and compute a weighted sum of the value vectors.',
#   '## Implementing Self Attention\nTo implement self attention in a deep learning model, we can utilize the TensorFlow library. \nA key component of self attention is the ability to compute attention weights based on input data.\n```python\nimport tensorflow as tf\n\n# Define self attention layer\nclass SelfAttention(tf.keras.layers.Layer):\n    def __init__(self, embed_dim, num_heads):\n        super(SelfAttention, self).__init__()\n        self.embed_dim = embed_dim\n        self.num_heads = num_heads\n        self.query_dense = tf.keras.layers.Dense(embed_dim)\n        self.key_dense = tf.keras.layers.Dense(embed_dim)\n        self.value_dense = tf.keras.layers.Dense(embed_dim)\n        self.combine_heads = tf.keras.layers.Dense(embed_dim)\n\n    def call(self, x):\n        # Compute query, key, and value vectors\n        query = self.query_dense(x)\n        key = self.key_dense(x)\n        value = self.value_dense(x)\n        # Compute attention weights\n        attention = tf.matmul(query, key, transpose_b=True)\n        attention = tf.nn.softmax(attention)\n        # Compute output\n        output = tf.matmul(attention, value)\n        output = self.combine_heads(output)\n        return output\n```\nTo initialize and train self attention weights, we need to define a loss function and an optimizer, then train the model using a dataset.\nSelf attention weights are typically initialized using a random normal distribution, and trained using backpropagation.\nFor production readiness, consider the following checklist:\n* Validate input data\n* Monitor model performance metrics\n* Test for edge cases, such as empty input sequences\nBy following these steps and considering the trade-offs between performance, cost, and complexity, developers can effectively implement self attention in their deep learning models.',
#   "## Common Mistakes in Self Attention\nSelf attention is a powerful mechanism, but its implementation can be tricky. \n* Vanishing gradients can occur when the input sequence is long, causing the gradients to become smaller as they backpropagate through the network, which can lead to slower training or convergence to a suboptimal solution. \nTo mitigate this, techniques like gradient clipping or using pre-trained models can be employed.\n\nWhen handling edge cases, such as zero-length input sequences, a simple solution is to pad the input with a special token or return a default value. \n```python\ndef self_attention(sequence):\n    if len(sequence) == 0:\n        return [0.0]  # return default value for empty sequence\n    # self attention implementation\n```\nProper weight initialization is crucial in self attention, as it can significantly affect the model's performance and convergence. \nIt is a best practice to initialize weights using techniques like Xavier initialization or Kaiming initialization, because this helps to avoid vanishing or exploding gradients by maintaining a stable variance across layers.",
#   '## Optimizing Self Attention for Performance\nTo optimize self attention for better performance and efficiency, several techniques can be employed. \nOne key approach is to use attention masking to reduce computational overhead. \nThis involves masking certain positions in the input sequence to prevent the model from attending to them, which can significantly reduce the number of computations required.\n\n* Using attention masking can be implemented by adding a mask to the attention weights, as shown in the following code:\n```python\nimport torch\nimport torch.nn as nn\nimport torch.nn.functional as F\n\n# Define attention mask\nattention_mask = torch.ones((sequence_length, sequence_length))\n\n# Apply attention mask\nattention_weights = attention_weights * attention_mask\n```\nIn comparison to other attention mechanisms, self attention has been shown to outperform them in many cases, particularly for longer input sequences. \nFor example, self attention can handle input sequences of varying lengths more effectively than other mechanisms.\n\nThe trade-offs between self attention and recurrent neural networks (RNNs) are also important to consider. \nWhile self attention can be more parallelizable and efficient than RNNs, it can also be more computationally expensive for very long input sequences. \nAs a best practice, use self attention when parallelization is crucial, because it allows for more efficient computation on GPUs. \nHowever, for very long sequences, RNNs may be a better choice due to their ability to handle sequential dependencies more efficiently.',
#   "## Debugging and Observability in Self Attention\nTo effectively debug and monitor self attention models, follow these steps:\n* Use visualization tools like TensorBoard or Weights & Biases to inspect self attention weights, allowing you to identify patterns and potential issues in the model's attention mechanisms.\n* Implement logging and metrics, such as tracking attention weight distributions and monitoring performance metrics like accuracy and loss, to monitor self attention model performance and detect anomalies.\nDebugging self attention models is crucial for production readiness, as it helps identify and fix issues that can significantly impact model performance and reliability, which is a best practice because it ensures that the model is functioning as expected and provides accurate results. \nKey considerations include checking for:\n  * vanishing or exploding gradients\n  * incorrect attention weight calculations\n  * overfitting or underfitting\nBy following these steps and considering these key points, developers can ensure their self attention models are thoroughly debugged and monitored, resulting in more reliable and accurate models.",
#   "## Conclusion and Next Steps\nTo apply self attention in deep learning projects, recall the key concepts: \n* self attention allows models to weigh input elements relative to each other.\nAdditional resources include the Transformer paper and PyTorch's documentation on self attention.\nExperiment with self attention in projects, considering performance and complexity trade-offs."],
#  'final': "# Understanding Self Attention in Deep Learning\n\n## Introduction to Self Attention\nSelf attention is a fundamental component in transformer models, allowing the model to attend to different parts of the input sequence simultaneously and weigh their importance. \n* Define self attention and its role in transformer models: Self attention is a mechanism that enables the model to compute representations of the input sequence by attending to all positions in the sequence and weighing their importance.\n* Show a minimal working example of self attention in PyTorch:\n```python\nimport torch\nimport torch.nn as nn\nimport torch.nn.functional as F\n\nclass SelfAttention(nn.Module):\n    def __init__(self, embed_dim):\n        super(SelfAttention, self).__init__()\n        self.query_linear = nn.Linear(embed_dim, embed_dim)\n        self.key_linear = nn.Linear(embed_dim, embed_dim)\n        self.value_linear = nn.Linear(embed_dim, embed_dim)\n\n    def forward(self, x):\n        query = self.query_linear(x)\n        key = self.key_linear(x)\n        value = self.value_linear(x)\n        attention_weights = F.softmax(torch.matmul(query, key.T) / math.sqrt(key.shape[-1]), dim=-1)\n        output = torch.matmul(attention_weights, value)\n        return output\n```\n* Explain the intuition behind self attention: The intuition behind self attention is to enable the model to focus on specific parts of the input sequence when computing representations, which is particularly useful for sequence-to-sequence tasks, as a best practice to improve performance by allowing the model to capture long-range dependencies, why: it reduces the need for recurrent neural networks (RNNs) and convolutional neural networks (CNNs) to capture these dependencies.\n\n## Core Concepts of Self Attention\nThe self attention mechanism is a fundamental component of transformer models, allowing them to weigh the importance of different input elements relative to each other. To understand self attention, we must first derive its equation from first principles. The self attention equation is derived by considering the input sequence as a set of vectors, where each vector represents a token or element in the sequence. The self attention mechanism computes the weighted sum of these vectors, where the weights are learned based on the input vectors themselves.\n\n* Derive the self attention equation from first principles:\n  The self attention equation can be derived as follows: \n  ```python\n  # Self attention equation\n  Attention(Q, K, V) = softmax(Q * K^T / sqrt(d)) * V\n  ```\n  where `Q`, `K`, and `V` are the query, key, and value vectors, respectively, and `d` is the dimensionality of the input vectors.\n\n* Compare self attention with traditional attention mechanisms:\n  Self attention differs from traditional attention mechanisms in that it does not rely on recurrent neural networks (RNNs) or convolutional neural networks (CNNs) to compute the attention weights. Instead, self attention uses the input vectors themselves to compute the attention weights, allowing for parallelization and improved performance.\n\n* Explain the role of query, key, and value vectors in self attention:\n  In self attention, the query, key, and value vectors play the following roles:\n  + Query vector (`Q`): represents the context in which the attention is being computed\n  + Key vector (`K`): represents the input elements being attended to\n  + Value vector (`V`): represents the values being weighted and summed\n  The query, key, and value vectors are typically obtained by linearly transforming the input vectors, allowing the self attention mechanism to capture complex relationships between the input elements. By using these vectors, self attention can effectively weigh the importance of different input elements and compute a weighted sum of the value vectors.\n\n## Implementing Self Attention\nTo implement self attention in a deep learning model, we can utilize the TensorFlow  ...
